# %%
import pandas as pd
from pycaret.classification import *

# Load your data
data = pd.read_csv(r'C:\Users\utkar\Desktop\cn proj\burp\final.csv')

# Initialize PyCaret environment for classification
classification_setup = setup(data = data, ignore_features = ['method','path','body'])

# Compare baseline models
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_2f19e_row11_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_2f19e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2f19e_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_2f19e_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2f19e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2f19e_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_2f19e_row0_col1" class="data row0 col1" >1840</td>
#     </tr>
#     <tr>
#       <th id="T_2f19e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2f19e_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_2f19e_row1_col1" class="data row1 col1" >class</td>
#     </tr>
#     <tr>
#       <th id="T_2f19e_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
tuned_model = tune_model(best_model)
# Out:
# <style type="text/css">
# #T_c8567_row10_col0, #T_c8567_row10_col1, #T_c8567_row10_col2, #T_c8567_row10_col3, #T_c8567_row10_col4, #T_c8567_row10_col5, #T_c8567_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_c8567">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c8567_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_c8567_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_c8567_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_c8567_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_c8567_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_c8567_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_c8567_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
plot_model(best_model, plot='learning')

# %%
evaluate_model(best_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
save_model(best_model,r'C:\Users\utkar\Desktop\cn proj\burp')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('label_encoding',
#                   TransformerWrapperWithInverse(exclude=None, include=None,
#                                                 transformer=LabelEncoder())),
#                  ('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['single_q', 'double_q', 'dashes',
#                                               'braces', 'spaces', 'badwords'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_em...
#                                                                fill_value=None,
# ...

# %%
new_data = pd.read_csv(r'C:\Users\utkar\Desktop\cn proj\burp\bad.csv')

# %%
predictions = predict_model(best_model, data=new_data)
# Out:
# <style type="text/css">
# </style>
# <table id="T_ff9dd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ff9dd_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ff9dd_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_ff9dd_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_ff9dd_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_ff9dd_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_ff9dd_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_ff9dd_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_ff9dd_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ff9dd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ff9dd_row0_col0" class="data row0 col0" >Logistic Regression</td>
# ...

# %%
predictions.to_csv(r'C:\Users\utkar\Desktop\cn proj\burp\lr_result.csv')
